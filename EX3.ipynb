# %%
print("24BAD050-JOHIYA SRI S")
import tensorflow as tf
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]
print("Training Data:", x_train.shape)
print("Validation Data:", x_val.shape)
print("Testing Data:", x_test.shape)

plt.figure(figsize=(10, 5))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")

plt.suptitle("CIFAR-10 Dataset")
plt.tight_layout()
plt.show()
# Out:
# 24BAD050-JOHIYA SRI S
# Training Data: (40000, 32, 32, 3)
# Validation Data: (10000, 32, 32, 3)
# Testing Data: (10000, 32, 32, 3)

# %%
print("24BAD050-JOHIYA SRI S")
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(32, 32, 3)),

    tf.keras.layers.Conv2D(32, (3, 3), activation="relu"),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation="relu"),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(128, (3, 3), activation="relu"),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, activation="relu"),

    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
print("\nCNN MODEL SUMMARY")
print("=" * 50)

model.summary()

print("\nModel compiled successfully!")
print("Optimizer: Adam")
print("Activation: ReLU")
print("Output Activation: Softmax")
print("Loss Function: Sparse Categorical Crossentropy")
# Out:
# 24BAD050-JOHIYA SRI S
#
# CNN MODEL SUMMARY
# ...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
print("24BAD050-JOHIYA SRI S")
import matplotlib.pyplot as plt
history = model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=10,
    batch_size=64,
    verbose=1
)

test_loss, test_accuracy = model.evaluate(
    x_test,
    y_test,
    verbose=0
)
print("\nCNN PERFORMANCE")
print("=" * 50)
print("Training Accuracy:",
      round(history.history["accuracy"][-1] * 100, 2), "%")

print("Validation Accuracy:",
      round(history.history["val_accuracy"][-1] * 100, 2), "%")

print("Training Loss:",
      round(history.history["loss"][-1], 4))

print("Validation Loss:",
      round(history.history["val_loss"][-1], 4))

print("Testing Accuracy:",
      round(test_accuracy * 100, 2), "%")

print("Testing Loss:",
      round(test_loss, 4))
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(8, 5))
plt.plot(
    history.history["loss"],
    label="Training Loss"
)

plt.plot(
    history.history["val_loss"],
    label="Validation Loss"
)

plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()
# Out:
# 24BAD050-JOHIYA SRI S
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8499 - loss: 0.4309 - val_accuracy: 0.7024 - val_loss: 0.9789
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 82ms/step - accuracy: 0.8695 - loss: 0.3738 - val_accuracy: 0.7160 - val_loss: 0.9768
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.8853 - loss: 0.3240 - val_accuracy: 0.7122 - val_loss: 1.0590
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.9003 - loss: 0.2856 - val_accuracy: 0.7156 - val_loss: 1.0748
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 0.9163 - loss: 0.2418 - val_accuracy: 0.7088 - val_loss: 1.1508
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 83ms/step - accuracy: 0.9242 - loss: 0.2147 - val_accuracy: 0.7081 - val_loss: 1.2332
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 82ms/step - accuracy: 0.9350 - loss: 0.1807 - val_accuracy: 0.7089 - val_loss: 1.3215
# Epoch 8/10
# ...

# %%
print("24BAD050-JOHIYA SRI S")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

class_names = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]
test_loss, test_accuracy = model.evaluate(
    x_test, y_test, verbose=0
)

print("PERFORMANCE ANALYSIS")
print("=" * 50)
print("Testing Accuracy:",
      round(test_accuracy * 100, 2), "%")
print("Testing Loss:",
      round(test_loss, 4))
predictions = model.predict(x_test, verbose=0)
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = y_test.flatten()
cm = confusion_matrix(
    actual_classes,
    predicted_classes
)

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.show()
print("\nCLASSIFICATION REPORT")
print("=" * 60)

print(
    classification_report(
        actual_classes,
        predicted_classes,
        target_names=class_names
    )
)
plt.figure(figsize=(12, 8))

for i in range(12):

    plt.subplot(3, 4, i + 1)

    plt.imshow(x_test[i])

    predicted = class_names[predicted_classes[i]]
    actual = class_names[actual_classes[i]]

    plt.title(
        "Predicted: " + predicted +
        "\nActual: " + actual
    )

    plt.axis("off")

plt.suptitle(
    "Sample Predictions"
)

plt.tight_layout()
plt.show()
misclassified = np.where(
    predicted_classes != actual_classes
)[0]

print("\nMisclassified Images:",
      len(misclassified))

plt.figure(figsize=(12, 8))

for i in range(min(12, len(misclassified))):

    index = misclassified[i]

    plt.subplot(3, 4, i + 1)

    plt.imshow(x_test[index])

    plt.title(
        "Predicted: " +
        class_names[predicted_classes[index]] +
        "\nActual: " +
        class_names[actual_classes[index]]
    )

    plt.axis("off")

plt.suptitle(
    "Misclassified Images"
)

plt.tight_layout()
plt.show()
print("\nSTRENGTHS OF CNN")
print("=" * 40)
print("1. Automatically learns important image features.")
print("2. Effective for image classification and recognition.")
print("3. Preserves spatial relationships between image features.")
print("4. Uses fewer parameters than fully connected networks.")

print("\nLIMITATIONS OF CNN")
print("=" * 40)
print("1. Requires considerable computational resources.")
print("2. Training can take significant time.")
print("3. May suffer from overfitting with limited training data.")
print("4. Performance depends on architecture and hyperparameter selection.")
# Out:
# 24BAD050-JOHIYA SRI S
# PERFORMANCE ANALYSIS
# ...
# Testing Accuracy: 69.64 %
# Testing Loss: 1.638
# CLASSIFICATION REPORT
# ...
#               precision    recall  f1-score   support
#
#     airplane       0.68      0.79      0.73      1000
#   automobile       0.79      0.82      0.81      1000
#         bird       0.55      0.64      0.59      1000
#          cat       0.56      0.43      0.49      1000
#         deer       0.68      0.58      0.62      1000
#          dog       0.55      0.68      0.60      1000
#         frog       0.80      0.73      0.76      1000
#        horse       0.80      0.70      0.75      1000
#         ship       0.82      0.82      0.82      1000
#        truck       0.80      0.77      0.78      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000
# Misclassified Images: 3036
# STRENGTHS OF CNN
# ...
